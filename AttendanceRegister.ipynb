# %%
import os
import pandas as pd
from datetime import datetime

# Directory containing your files
directory = r"/content/Atten2"

# Initialize an empty list to store DataFrames
df_list = []

# Function to standardize date format
def standardize_date(date_str):
    # Convert the input to a string (in case it's a float or other type)
    date_str = str(date_str)

    try:
        # Try parsing the date in "DD/MM/YY" format (e.g., 19/12/23)
        date_obj = datetime.strptime(date_str, "%d/%m/%y")
    except ValueError:
        try:
            # Try parsing the date in "D/M/YYYY" format (e.g., 1/10/2024)
            date_obj = datetime.strptime(date_str, "%d/%m/%Y")
        except ValueError:
            try:
                # Try parsing the date in "DD-B-YYYY" format (e.g., 26-August-2024)
                date_obj = datetime.strptime(date_str, "%d-%B-%Y")
            except ValueError:
                # If the date is already in the correct format or cannot be parsed, return as-is
                return date_str
    # Format the datetime object into the desired format (DD-MMM-YYYY)
    return date_obj.strftime("%d-%b-%Y")

# Loop through all files in the directory
for filename in os.listdir(directory):
    file_path = os.path.join(directory, filename)

    # Process only CSV files
    if filename.endswith(".csv"):
        print(f"Processing CSV file: {filename}")

        # Read the CSV file
        df = pd.read_csv(file_path)

        # Standardize column names (strip whitespace and ensure consistent case)
        df.columns = df.columns.str.strip().str.replace(" ", "_")

        # Rename columns as per requirements
        df = df.rename(columns={
            "Bootcamp_name": "name",
            "CohortNo": "cohort",
            "Date": "date",
            "Student_ID": "studentid",
            "Attendance": "attendance_flag"
        })

        # Check if 'studentid' column exists
        if "studentid" not in df.columns:
            print(f"⚠️ 'studentid' column not found in file: {filename}. Skipping this file.")
            continue

        # Check if 'attendance_flag' column already exists
        if "attendance_flag" in df.columns:
            # Rename the existing 'attendance_flag' column to avoid conflicts
            df = df.rename(columns={"attendance_flag": "Attendance_Original"})

        # Standardize date columns
        date_columns = [col for col in df.columns if col not in ["studentid", "name", "cohort"]]
        for col in date_columns:
            df[col] = df[col].astype(str).apply(standardize_date)  # Convert to string before processing

        # Convert the DataFrame to long format
        df_long = df.melt(id_vars=["studentid", "name", "cohort"], var_name="date", value_name="attendance_flag")

        # Append the long format DataFrame to the list
        df_list.append(df_long)

# Combine all DataFrames
if df_list:
    final_df = pd.concat(df_list, ignore_index=True)

    # Save merged data to a new CSV file
    output_path = os.path.join(directory, "merged_attendance_csv_only.csv")
    final_df.to_csv(output_path, index=False)

    print(f"✅ Merged CSV files saved at: {output_path}")
else:
    print("⚠️ No valid CSV files found in the directory.")
# Out:
# Processing CSV file: IntroductionToAI_Cohort6.csv
# Processing CSV file: Computer_VisionC1.csv
# Processing CSV file: Attendance Register - ML Fundamentals - Cohort 1.csv
# Processing CSV file: MLFundamentals_Cohort3.csv
# Processing CSV file: DataPreparationforGenAIC2.csv
# Processing CSV file: PythonFundamentals_Cohort1.csv
# Processing CSV file: GenerativeAI_Cohort3.csv
# Processing CSV file: Attendance Register - Generative AI Introduction&Large Language Model Introduction - Cohort 1.csv
# Processing CSV file: MLFundamentals_Cohort5.csv
# Processing CSV file: MLFundamentals_Cohort2.csv
# Processing CSV file: IntroductionToAI_Cohort10.csv
# Processing CSV file: NLP_LLMFinetuning_Cohort3.csv
# Processing CSV file: GenerativeAI_Cohort2.csv
# Processing CSV file: DataPreparationforGenAIC4.csv
# Processing CSV file: PythonFundamentals_Cohort4.csv
# Processing CSV file: PythonFundamentals_Cohort2.csv
# Processing CSV file: NLP_LLMFinetuning_Cohort2.csv
# Processing CSV file: NLP_LLMFinetuning_Cohort1.csv
# Processing CSV file: IntroductionToAI_Cohort7.csv
# Processing CSV file: IntroductionToAI_Cohort1.csv
# Processing CSV file: GenerativeAI_Cohort5.csv
# Processing CSV file: IntroductionToAI_Cohort5.csv
# Processing CSV file: IntroductionToAI_Cohort4.csv
# Processing CSV file: IntroductionToAI_Cohort2.csv
# Processing CSV file: DataPreparationforGenAIC3.csv
# Processing CSV file: GenerativeAI_Cohort4.csv
# Processing CSV file: MLFundamentals_Cohort4.csv
# Processing CSV file: IntroductionToAI_Cohort8.csv
# Processing CSV file: DataPreparationforGenAIC1.csv
# Processing CSV file: Computer_VisionC2.csv
# Processing CSV file: PythonFundamentals_Cohort3.csv
# Processing CSV file: IntroductionToAI_Cohort3.csv
# Processing CSV file: IntroductionToAI_Cohort9.csv
# Processing CSV file: Computation_Distribution.csv
# ✅ Merged CSV files saved at: /content/Atten2/merged_attendance_csv_only.csv

# %%
final_df['cohort'].unique()
# Out:
# array(['C6', 'C1', 'C3', 'C2', 'C5', 'C10', 'C4', 'C7', 'C8', 'C9'],
#       dtype=object)

# %%
final_df['name'].unique()
# Out:
# array(['Introduction to AI', 'Computer Vision', 'ML Fundamentals',
#        'Data Preparation for GenAI', 'Python Fundamentals',
#        'Generative AI Introduction & Large Language Model Introduction',
#        'NLP and LLM Finetuning', 'Computation Distribution'], dtype=object)

# %%
final_df[final_df['name'] == 'Python Fundamentals']
# Out:
#      studentid                 name cohort             date attendance_flag
# 757   Stud0010  Python Fundamentals     C1  15-January-2024               P
# 758   Stud0013  Python Fundamentals     C1  15-January-2024               P
# 759   Stud0025  Python Fundamentals     C1  15-January-2024               P
# 760   Stud0046  Python Fundamentals     C1  15-January-2024               P
# 761   Stud0059  Python Fundamentals     C1  15-January-2024               P
# ...        ...                  ...    ...              ...             ...
# 6598  Stud0345  Python Fundamentals     C3     13-June-2024             p\r
# 6599  Stud0349  Python Fundamentals     C3     13-June-2024             p\r
# 6600  Stud0359  Python Fundamentals     C3     13-June-2024             x\r
# 6601  Stud0366  Python Fundamentals     C3     13-June-2024             p\r
# 6602  Stud0376  Python Fundamentals     C3     13-June-2024             p\r
#
# [292 rows x 5 columns]
